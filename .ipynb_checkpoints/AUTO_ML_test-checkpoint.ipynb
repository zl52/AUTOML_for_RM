# %% [markdown]
# # Import Function

# %%
# import sys
# sys.path.append('C://Users/Administrator/Desktop/packages/lzp_utils')

# %%
pwd
# Out:
# 'E:\\zipeng.lin\\repo\\AUTOML'

# %%
from import_packages import *
from tools import *
from sample_exploration import get_od_label
from data_aggregation import *
from data_cleaning import DataFilter, plot_missingno
from sample_exploration import get_pos_rate,desc_stat,feats_coverage_stat,sample_coverage_stat
from sample_splitter import sample_splitter
from feature_transformation import FeatureTransformer
from feature_trimming import FeatureTrimmer
from feature_scaling import FeatureScaler
from feature_encoding import FeatureEncoder
from feature_imputation import FeatureImputer
from feature_selection import FeatureFilter
from feature_evaluation import get_vif_cor, plot_hist_all, plot_joint_dist_all
from model_training import BAYESIAN_OPTIMIZATION, cv_check, xgbt, model_toolkit, model_selection
from model_evaluation import plot_all_figures
from recoding_statement import GenerateOutputFiles

# %% [markdown]
# # Import Data

# %%
path = "E://zipeng.lin/20190122_cscore_v1/data/"

# %% [markdown]
# ## Import Data

# %%
df = df_ori = pd.read_csv("E://zipeng.lin/20190122_cscore_v1/data/" + 'maimaiche_data.csv', encoding='utf-8', sep='	')
del df['Unnamed: 0']
df = df[df.label != -1]

#--------------------------------------------------------------------------------------------------#
"""
data cleaning
"""
# Out:
# '\ndata cleaning\n'

# %% [markdown]
# # Global Definition

# %%
# column of labels for model training
label = 'label'

#--------------------------------------------------------------------------------------------------#
# column of datetimes
dt_col = 'loan_date'

#--------------------------------------------------------------------------------------------------#
# column of unique ids
uid = 'docid'

#--------------------------------------------------------------------------------------------------#
# column of overdue days
od_col = 'max_delay_date'

#--------------------------------------------------------------------------------------------------#
# columns need to be excluded from feature engineering and model training
exclude_list = [] + \
               [dt_col] + [uid]# + [od_col]

#--------------------------------------------------------------------------------------------------#
# columns of boolean targets for data exploration if exists
# target = ['d0', 'd1', 'd3', 'd7']
target = ['label']

#--------------------------------------------------------------------------------------------------#
# set boolean targets if none is given
if len(set(target) - set(df.columns)) != 0:
    df = get_od_label(df, OD_TARGET=OD_TARGET, col=od_col, drop=False, event=1)
    
#--------------------------------------------------------------------------------------------------#
# define output files' name
model_name = 'Sample_Model'

ud_recoding_file = 'Feature_Recoding_Statement_for_ud_%s.txt'%model_name
lr_recoding_file = 'Feature_Recoding_Statement_for_lr_%s.txt'%model_name
woe_recoding_stat_file = 'Feature_Woe_Recoding_Statistics_for_%s.xlsx'%model_name
feature_stat_file = 'Feature_Statistical_Summary_for_%s.xlsx'%model_name
lr_model_equation_file = 'Equation_for_LR_%s.txt'%model_name
lr_model_summary_file = 'Summary_for_LR_%s.xlsx'%model_name

# %%
# use lR model or not
model_linear = True

#--------------------------------------------------------------------------------------------------#
# whether transform, trim, scale, woe-encode and impute features
useTransformr = False
useTrimmr = False
useScalr = False
useWoeEncoder = True
useImputr = True
#--------------------------------------------------------------------------------------------------#
if model_linear:
    useTransformr = True
    useTrimmr = True
    useScalr = True
    useWoeEncoder = True
    useImputr = True
#--------------------------------------------------------------------------------------------------#
# whether use iv and model's feature importance to filter features (XGBoost, RandomForest and LR models are supported)
useIvFiltr = True
useXgbfiFiltr = True
useRFfiFiltr = True
useLRFiltr = True
#--------------------------------------------------------------------------------------------------#
# number of remaining features after each step
xgb_feat_cnt = 25
rf_feat_cnt = 22
lr_feat_cnt = 18

# %% [markdown]
# # AUTO ML

# %% [markdown]
# ## DATA CLEANING

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################    1. DATA CLEANING    ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Visualize missing-value statistics
#--------------------------------------------------------------------------------------------------#
plot_missingno(df)

# %%
# Filter columns with number of unique values below defined threshold. Filter columns with missing rates
# above defined threshold. Filter columns with a value of high frequency above defined threshold
#--------------------------------------------------------------------------------------------------#
# : params nunique_thr: threshold of unique values number
# : params missing_rate_thr: missing rate threshold
# : params HF_value_thr: threshold of high-frequency value's occurrence propability
# : params drop_cols: list of columns should be removed manually
filtr = DataFilter(nunique_thr=2, missing_rate_thr=0.99, HF_value_thr=0.98, silent=False,
                    exclude_list=['name', 'mobile', 'create_date', 'audit_info_id', 'tj_yys_audit_info_id',
                               'yys_v2Flag_name', 'max_cur_term', 'max_delay_date', 'delay_over_30'])
#--------------------------------------------------------------------------------------------------#
df = filtr.fit_transform(df)
# Out:
# Statistics of columns to be dropped
#
#                           unique_value_cnt missing_rate  HF_value_pct
# yys_specialCate15TalkNum                 0      100.00%           NaN
# yys_specialCate13TalkNum                 0      100.00%           NaN
# yys_specialCate16TalkNum                 0      100.00%           NaN
# rn                                       1        0.00%      1.000000
# yys_AveMonthlyConsume                    0      100.00%           NaN
# yys_friendMap_2                          0      100.00%           NaN
# gzt_is_reject                            1        0.05%      0.999471
# yys_specialCate15TalkNum                 0      100.00%           NaN
# yys_specialCate13TalkNum                 0      100.00%           NaN
# yys_specialCate16TalkNum                 0      100.00%           NaN
# yys_AveMonthlyConsume                    0      100.00%           NaN
# yys_friendMap_2                          0      100.00%           NaN
# rn                                       1        0.00%      1.000000
# gzt_is_reject                            1        0.05%      0.999471
# geo_A4_RSL                               4        0.15%      0.994815
# agentr_blacklist                        32        0.00%      0.996508
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Missing rates of these columns exceed defined threshold: 0.990000
#
#
# yys_specialCate15TalkNum
#  yys_specialCate13TalkNum
#  yys_specialCate16TalkNum
#  rn
#  yys_AveMonthlyConsume
#  yys_friendMap_2
#  gzt_is_reject
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Unique values of these columns do not exceed defined threshold: 2.000000
#
#
# yys_specialCate15TalkNum
#  yys_specialCate13TalkNum
#  yys_specialCate16TalkNum
#  yys_AveMonthlyConsume
#  yys_friendMap_2
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Percentages of high-frequency-values of these columns exceed defined threshold: 0.980000
#
#
# rn
#  gzt_is_reject
#  geo_A4_RSL
#  agentr_blacklist
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Columns shown as below are dropped
#
#
# yys_specialCate15TalkNum
#  yys_specialCate13TalkNum
#  yys_specialCate16TalkNum
#  rn
#  yys_AveMonthlyConsume
#  yys_friendMap_2
#  gzt_is_reject
#  yys_specialCate15TalkNum
#  yys_specialCate13TalkNum
#  yys_specialCate16TalkNum
#  yys_AveMonthlyConsume
#  yys_friendMap_2
#  rn
#  gzt_is_reject
#  geo_A4_RSL
#  agentr_blacklist
#  name
#  mobile
#  create_date
#  audit_info_id
#  tj_yys_audit_info_id
#  yys_v2Flag_name
#  max_cur_term
#  max_delay_date
#  delay_over_30

# %% [markdown]
# ## DATA AGGREGATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################  2. DATA AGGREGATION   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Apply RFM rule to do feature engineering where samples are aggregated by defined aggregate keys 
# and limitted by defined time spans in combinations

# %% [markdown]
# ## SAMPLE EXPLORATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
###################################### 3. SAMPLE EXPLORATION  ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# 1.Calculate positive rate (dependent variable's ratio of being positive)
# 2.Generate each feature's descriptive statistical summary, including missing count, missing rate, coverage count, coverage rate, 
#   unique values count, high-frequency value, high-frequency value's count, high-frequency value's probability of occurrence
# 3.Calculate positive rate of samples covered and uncovered by each feature
# 4.Calculate fully or partially covered sample and totally uncovered sample's positive rate
#--------------------------------------------------------------------------------------------------#
dr = get_pos_rate(df, target=target, is_ratio_pct=True, silent=False, event=1)
dcp_stat = desc_stat(df, target=target, is_ratio_pct=True, use_formater=True, silent=False);dcp_stat.head()
fc_stat = feats_coverage_stat(df, target=target, is_ratio_pct=True, sort_value=True, silent=False, event=1)
# sc_stat = sample_coverage_stat(df, target=target, exclude_col=[], silent=False, event=1)
# Out:
# Calculate each target's positive rate (dependent variable's ratio of being positive)
#
#                label
# positive_rate  20.8%
#
# ________________________________________________________________________________________________________________________
#
# Generate descriptive statistical summary, including missing count, missing rate,
#  coverage count, coverage rate, unique values count, high-frequency, value, high-frequency value's count, high-frequency value's
#  probability of occurrence
#
# ________________________________________________________________________________________________________________________
#                                   1%     25%     50%     75%      99%  count  \
# umeng_credit_score             -1.00  542.00  552.00  565.00   620.00   8352
# yys_monthlyAvgConsume           9.66   76.30  122.88  185.66   441.41   6745
# td_final_score                  0.00    9.00   20.00   34.00    73.00   9451
# yys_specialCate5CallNum         0.00    0.00    0.00    0.00    21.00   6745
# yys_specialCate2CalledSeconds   0.00    0.00    0.00    0.00  1902.16   6745
#
#                                     max    mean    min     std  missing_cnt  \
# umeng_credit_score               716.00  531.30  -1.00  112.05         1099
# yys_monthlyAvgConsume           3571.51  140.10   0.00  102.19         2706
# td_final_score                    79.00   22.92   0.00   17.47            0
# yys_specialCate5CallNum          574.00    1.28   0.00   11.55         2706
# yys_specialCate2CalledSeconds  21752.00   87.54   0.00  513.48         2706
#
#                               missing_rate  coverage_count coverage_rate  \
# umeng_credit_score                  11.63%            8352        88.37%
# yys_monthlyAvgConsume               28.63%            6745        71.37%
# td_final_score                       0.00%            9451       100.00%
# yys_specialCate5CallNum             28.63%            6745        71.37%
# yys_specialCate2CalledSeconds       28.63%            6745        71.37%
#
#                                unique_value_cnt HF_value  HF_value_cnt  \
# umeng_credit_score                          198      552          1226
# yys_monthlyAvgConsume                      5860        0            34
# td_final_score                               79        0           803
# yys_specialCate5CallNum                      67        0          5584
# yys_specialCate2CalledSeconds               582        0          5704
#
#                               HF_value_pct
# umeng_credit_score                  12.97%
# yys_monthlyAvgConsume                0.36%
# td_final_score                       8.50%
# yys_specialCate5CallNum             59.08%
# yys_specialCate2CalledSeconds       60.35%
# Calculate positive rate of samples covered and uncovered by each feature
#
#                                      label
# geo_B7_RSL                UNCOVERED  32.3%
# baidu_risk_blacklevel     COVERED    29.1%
# yys_specialCate2CalledNum UNCOVERED  27.5%
# yys_specialCate3CallNum   UNCOVERED  27.5%
# yys_specialCate6TalkNum   UNCOVERED  27.5%
# yys_specialCate2CallNum   UNCOVERED  27.5%
# yys_specialCate4CallNum   UNCOVERED  27.5%
# yys_specialCate4CalledNum UNCOVERED  27.5%
# yys_fakeCallNum           UNCOVERED  27.5%
# yys_specialCate5CalledNum UNCOVERED  27.5%
#
# ________________________________________________________________________________________________________________________

# %%
# plot historgrams for all original numerical variables
#--------------------------------------------------------------------------------------------------#
plot_hist_all(df, target=['label'], extr_outlier_removed=True)

# %%
# plot barplot for categorical variables and violinplot for continuous variables

#--------------------------------------------------------------------------------------------------#
plot_joint_dist_all(df, target=label, nunique_thr=10, extr_outlier_removed=True)

# %% [markdown]
# ## SAMPLE_SPLITTER

# %%
# df_ol is used to test recoding statements and can be regarded as online data
df_ol = df.iloc[:2]
df = df.iloc[2:]

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################   4. SAMPLE SPLITTER   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

#     Split samples into two or three sets: train, validation (and oot(test)) sets.
#     oot(test) set contains lastest samples
#--------------------------------------------------------------------------------------------------#
#     : param df: samples to be splitted
#     : param label: boolean label
#     : param dt_col: col indicating datetime
#     : param id: unique key
#     : param val_size: size of validation set (by ratio)
#     : param oot_size: size of oot(test) set
#     : param split_by_ratio: whether to split oot(test) set by defined ratio
#     : param method: if 'oot' is chosen, output will contain three sets: train, validation and oot(test) sets
#                     if 'random' is chosen, output will contain two sets: train and validation sets
#     : param drop_dt_col: whether to drop dt_col
#     : param random_state: seed
df_tr, df_va, df_te = sample_splitter(df, label=None, dt_col=dt_col, val_size=0.2, test_size=0.1, split_by_ratio=True,
                                                                 method='oot', drop_dt_col=False, random_state=7)
# Out:
# train set ranges from 2018-04-28 to 2018-08-13
# test set ranges from 2018-08-13 to 2018-10-25

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################   WRITE OUTPUT FILES   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################
# intialize recoding statement dictionary and feature dictionary recoding changes of feature names
rs = GenerateOutputFiles(df, label, target=target, exclude_list=exclude_list)

#--------------------------------------------------------------------------------------------------#
# generate woe recoding profile
rs.generate_lr_recoding_dict(lr_recoding_file)
feat_stat = rs.write_statistical_summary(feature_stat_file, encoding="utf-8");feat_stat
woe_stat = rs.woe_recoding_stat(woe_recoding_stat_file, encoding="utf-8");woe_stat
# Out:
#                                    1%     25%     50%      75%       99%  \
# baidu_risk_blacklevel             nan     nan     nan      nan       nan
# geo_A3_RSL                        nan     nan     nan      nan       nan
# geo_B7_RSL                        nan     nan     nan      nan       nan
# riskScore                       -3.00   -2.00   -2.00     0.00      5.00
# td_final_decision                 nan     nan     nan      nan       nan
# td_final_score                   0.00    9.00   20.00    34.00     73.00
# umeng_app_score                 -1.00  535.00  540.00   558.00    638.00
# umeng_credit_score              -1.00  542.00  552.00   565.00    620.00
# umeng_device_os                   nan     nan     nan      nan       nan
# umeng_device_price               1.00    2.00    3.00     4.00      5.00
# umeng_device_rank                0.00    0.00    0.00     1.00      3.00
# umeng_device_score             436.00  584.00  635.00   675.00    735.00
# umeng_id_score                 467.00  510.00  532.00   697.00    850.00
# umeng_interest_score            -1.00  507.00  568.00   604.00    657.00
# umeng_location_score           493.00  571.00  604.00   645.00    743.00
# yys_fakeCallNum                  0.00    0.00    1.00     4.00     78.00
# yys_friendMap                     nan     nan     nan      nan       nan
# yys_monthlyAvgConsume            9.66   76.29  122.87   185.68    441.42
# yys_phoneLocation                 nan     nan     nan      nan       nan
# yys_specialCate2CallNum          0.00    0.00    0.00     0.00      6.00
# yys_specialCate2CalledNum        0.00    0.00    0.00     0.00      9.00
# yys_specialCate2CalledSeconds    0.00    0.00    0.00     0.00   1902.27
# yys_specialCate3CallNum          0.00    0.00    0.00     0.00     11.00
# yys_specialCate3CalledNum        0.00    0.00    0.00     0.00     10.00
# yys_specialCate3CalledSeconds    0.00    0.00    0.00     0.00   2009.26
# yys_specialCate4CallNum          0.00    3.00   10.00    35.00    376.99
# yys_specialCate4CalledNum        0.00    2.00    8.00    29.00    368.14
# yys_specialCate4CalledSeconds    0.00  120.00  656.50  2672.00  33368.39
# yys_specialCate5CallNum          0.00    0.00    0.00     0.00     21.00
# yys_specialCate5CalledNum        0.00    0.00    0.00     0.00     22.00
# yys_specialCate5CalledSeconds    0.00    0.00    0.00     0.00   2054.16
# yys_specialCate6TalkNum          0.00    2.00    7.00    16.00    205.71
# yys_specialCate7TalkNum          0.00    2.00    6.00    13.00    114.57
#
#                                count        max     mean     min      std  \
# baidu_risk_blacklevel            659        nan      nan     nan      nan
# geo_A3_RSL                      9415        nan      nan     nan      nan
# geo_B7_RSL                      9418        nan      nan     nan      nan
# riskScore                       9449      10.00    -1.00   -3.00     1.97
# td_final_decision               9449        nan      nan     nan      nan
# td_final_score                  9449      79.00    22.92    0.00    17.47
# umeng_app_score                 8217     749.00   534.18   -1.00    92.91
# umeng_credit_score              8350     716.00   531.29   -1.00   112.06
# umeng_device_os                 7840        nan      nan     nan      nan
# umeng_device_price              7403       5.00     3.27    1.00     1.18
# umeng_device_rank               7349       3.00     0.74    0.00     0.88
# umeng_device_score              8162     782.00   624.69  383.00    66.15
# umeng_id_score                  8407     850.00   588.21  326.00   127.37
# umeng_interest_score            7559     762.00   483.19   -1.00   209.11
# umeng_location_score            8190     797.00   609.24  396.00    52.76
# yys_fakeCallNum                 6744     396.00     5.75    0.00    18.34
# yys_friendMap                   6743        nan      nan     nan      nan
# yys_monthlyAvgConsume           6744    3571.51   140.10    0.00   102.19
# yys_phoneLocation               6744        nan      nan     nan      nan
# yys_specialCate2CallNum         6744     203.00     0.31    0.00     3.69
# yys_specialCate2CalledNum       6744     268.00     0.59    0.00     4.53
# yys_specialCate2CalledSeconds   6744   21752.00    87.55    0.00   513.51
# yys_specialCate3CallNum         6744     132.00     0.67    0.00     3.45
# yys_specialCate3CalledNum       6744     130.00     0.65    0.00     3.38
# yys_specialCate3CalledSeconds   6744   11599.00    93.98    0.00   460.87
# yys_specialCate4CallNum         6744    1866.00    36.93    0.00    80.84
# yys_specialCate4CalledNum       6744    2533.00    33.65    0.00    79.13
# yys_specialCate4CalledSeconds   6744  198710.00  2998.81    0.00  7096.42
# yys_specialCate5CallNum         6744     574.00     1.28    0.00    11.55
# yys_specialCate5CalledNum       6744     432.00     1.17    0.00    10.31
# yys_specialCate5CalledSeconds   6744   37542.00   107.47    0.00   791.49
# yys_specialCate6TalkNum         6744    1339.00    17.69    0.00    49.76
# yys_specialCate7TalkNum         6744    1738.00    13.05    0.00    42.05
#
#                                missing_cnt missing_rate  coverage_count  \
# baidu_risk_blacklevel                 8790       93.03%             659
# geo_A3_RSL                              34        0.36%            9415
# geo_B7_RSL                              31        0.33%            9418
# riskScore                                0        0.00%            9449
# td_final_decision                        0        0.00%            9449
# td_final_score                           0        0.00%            9449
# umeng_app_score                       1232       13.04%            8217
# umeng_credit_score                    1099       11.63%            8350
# umeng_device_os                       1609       17.03%            7840
# umeng_device_price                    2046       21.65%            7403
# umeng_device_rank                     2100       22.22%            7349
# umeng_device_score                    1287       13.62%            8162
# umeng_id_score                        1042       11.03%            8407
# umeng_interest_score                  1890       20.00%            7559
# umeng_location_score                  1259       13.32%            8190
# yys_fakeCallNum                       2705       28.63%            6744
# yys_friendMap                         2706       28.64%            6743
# yys_monthlyAvgConsume                 2705       28.63%            6744
# yys_phoneLocation                     2705       28.63%            6744
# yys_specialCate2CallNum               2705       28.63%            6744
# yys_specialCate2CalledNum             2705       28.63%            6744
# yys_specialCate2CalledSeconds         2705       28.63%            6744
# yys_specialCate3CallNum               2705       28.63%            6744
# yys_specialCate3CalledNum             2705       28.63%            6744
# yys_specialCate3CalledSeconds         2705       28.63%            6744
# yys_specialCate4CallNum               2705       28.63%            6744
# yys_specialCate4CalledNum             2705       28.63%            6744
# yys_specialCate4CalledSeconds         2705       28.63%            6744
# yys_specialCate5CallNum               2705       28.63%            6744
# yys_specialCate5CalledNum             2705       28.63%            6744
# yys_specialCate5CalledSeconds         2705       28.63%            6744
# yys_specialCate6TalkNum               2705       28.63%            6744
# yys_specialCate7TalkNum               2705       28.63%            6744
#
#                               coverage_rate  unique_value_cnt HF_value  \
# baidu_risk_blacklevel                 6.97%                 4        D
# geo_A3_RSL                           99.64%                 6    \3\""
# geo_B7_RSL                           99.67%                 4    \0\""
# riskScore                           100.00%                23       -2
# td_final_decision                   100.00%                 2   Review
# td_final_score                      100.00%                79        0
# umeng_app_score                      86.96%               202      535
# umeng_credit_score                   88.37%               198      552
# umeng_device_os                      82.97%                 3  android
# umeng_device_price                   78.35%                 5        3
# umeng_device_rank                    77.78%                 4        0
# umeng_device_score                   86.38%               157      675
# umeng_id_score                       88.97%                67      510
# umeng_interest_score                 80.00%               269       -1
# umeng_location_score                 86.68%               200      542
# yys_fakeCallNum                      71.37%               129        0
# yys_friendMap                        71.36%                32       广东
# yys_monthlyAvgConsume                71.37%              5859        0
# yys_phoneLocation                    71.37%                31       广东
# yys_specialCate2CallNum              71.37%                35        0
# yys_specialCate2CalledNum            71.37%                32        0
# yys_specialCate2CalledSeconds        71.37%               582        0
# yys_specialCate3CallNum              71.37%                38        0
# yys_specialCate3CalledNum            71.37%                33        0
# yys_specialCate3CalledSeconds        71.37%               619        0
# yys_specialCate4CallNum              71.37%               363        0
# yys_specialCate4CalledNum            71.37%               363        0
# yys_specialCate4CalledSeconds        71.37%              3286        0
# yys_specialCate5CallNum              71.37%                67        0
# yys_specialCate5CalledNum            71.37%                63        0
# yys_specialCate5CalledSeconds        71.37%               621        0
# yys_specialCate6TalkNum              71.37%               219        0
# yys_specialCate7TalkNum              71.37%               167        2
#
#                                HF_value_cnt HF_value_pct        iv
# baidu_risk_blacklevel                   557        5.89%  0.021994
# geo_A3_RSL                             7082       74.95%  0.027661
# geo_B7_RSL                             8560       90.59%  0.005681
# riskScore                              2812       29.76%  0.122067
# td_final_decision                      4790       50.69%  0.265018
# td_final_score                          803        8.50%  0.387907
# umeng_app_score                        2652       28.07%  0.087271
# umeng_credit_score                     1226       12.97%  0.031494
# umeng_device_os                        5334       56.45%  0.017052
# umeng_device_price                     2163       22.89%  0.028968
# umeng_device_rank                      3759       39.78%  0.009061
# umeng_device_score                     1027       10.87%  0.025899
# umeng_id_score                         2883       30.51%  0.005539
# umeng_interest_score                   1146       12.13%  0.027913
# umeng_location_score                    321        3.40%  0.039258
# yys_fakeCallNum                        2702       28.60%  0.083335
# yys_friendMap                           532        5.63%  0.124963
# yys_monthlyAvgConsume                    34        0.36%  0.090072
# yys_phoneLocation                       532        5.63%  0.127723
# yys_specialCate2CallNum                6329       66.98%  0.081393
# yys_specialCate2CalledNum              5702       60.35%  0.074847
# yys_specialCate2CalledSeconds          5703       60.36%  0.078145
# yys_specialCate3CallNum                5639       59.68%  0.108049
# yys_specialCate3CalledNum              5473       57.92%  0.075495
# yys_specialCate3CalledSeconds          5474       57.93%  0.081856
# yys_specialCate4CallNum                 833        8.82%  0.078626
# yys_specialCate4CalledNum               804        8.51%  0.083224
# yys_specialCate4CalledSeconds           804        8.51%  0.087533
# yys_specialCate5CallNum                5583       59.09%  0.069106
# yys_specialCate5CalledNum              5313       56.23%  0.063548
# yys_specialCate5CalledSeconds          5313       56.23%  0.068541
# yys_specialCate6TalkNum                 876        9.27%  0.079765
# yys_specialCate7TalkNum                 591        6.25%  0.099346
#                          feature          iv          woe  \
# 0                 td_final_score    0.387907     -1.37581
# 0                 td_final_score    0.387907    -0.870084
# 0                 td_final_score    0.387907    -0.578576
# 0                 td_final_score    0.387907    -0.267633
# 0                 td_final_score    0.387907    0.0584476
# 0                 td_final_score    0.387907      0.23531
# 0                 td_final_score    0.387907     0.375467
# 0                 td_final_score    0.387907     0.555832
# 0                 td_final_score    0.387907      0.67415
# 0                 td_final_score    0.387907     0.913313
# 0                 td_final_score    0.387907            0
# 0                      riskScore    0.122067    -0.520928
# 0                      riskScore    0.122067     0.105946
# 0                      riskScore    0.122067    -0.233269
# 0                      riskScore    0.122067     0.248278
# 0                      riskScore    0.122067   -0.0606666
# 0                      riskScore    0.122067     0.491554
# 0                      riskScore    0.122067     0.627741
# 0                      riskScore    0.122067            0
# 0        yys_specialCate3CallNum    0.108049    -0.295096
# 0        yys_specialCate3CallNum    0.108049     0.231186
# 0        yys_specialCate3CallNum    0.108049     0.494923
# 0        yys_specialCate3CallNum    0.108049     0.368675
# 0        yys_specialCate7TalkNum   0.0993456    -0.431671
# 0        yys_specialCate7TalkNum   0.0993456    -0.291834
# 0        yys_specialCate7TalkNum   0.0993456       -0.548
# 0        yys_specialCate7TalkNum   0.0993456    -0.332432
# 0        yys_specialCate7TalkNum   0.0993456   -0.0126727
# 0        yys_specialCate7TalkNum   0.0993456    -0.284232
# 0        yys_specialCate7TalkNum   0.0993456    0.0488216
# 0        yys_specialCate7TalkNum   0.0993456   -0.0601669
# 0        yys_specialCate7TalkNum   0.0993456     0.311486
# 0        yys_specialCate7TalkNum   0.0993456    0.0966058
# 0        yys_specialCate7TalkNum   0.0993456     0.368675
# 0          yys_monthlyAvgConsume   0.0900715    -0.381661
# 0          yys_monthlyAvgConsume   0.0900715    -0.122624
# 0          yys_monthlyAvgConsume   0.0900715   -0.0256112
# 0          yys_monthlyAvgConsume   0.0900715    -0.259285
# 0          yys_monthlyAvgConsume   0.0900715    -0.108508
# 0          yys_monthlyAvgConsume   0.0900715    -0.473918
# 0          yys_monthlyAvgConsume   0.0900715     0.165058
# 0          yys_monthlyAvgConsume   0.0900715    0.0467202
# 0          yys_monthlyAvgConsume   0.0900715     0.325389
# 0          yys_monthlyAvgConsume   0.0900715     0.368675
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.145317
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.471317
# 0  yys_specialCate4CalledSeconds   0.0875334   -0.0232228
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.412356
# 0  yys_specialCate4CalledSeconds   0.0875334   -0.0701064
# 0  yys_specialCate4CalledSeconds   0.0875334    0.0191686
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.451315
# 0  yys_specialCate4CalledSeconds   0.0875334    0.0481363
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.419211
# 0  yys_specialCate4CalledSeconds   0.0875334    -0.173721
# 0  yys_specialCate4CalledSeconds   0.0875334     0.368675
# 0                umeng_app_score   0.0872713     0.119229
# 0                umeng_app_score   0.0872713    -0.667739
# 0                umeng_app_score   0.0872713    -0.186296
# 0                umeng_app_score   0.0872713    -0.335579
# 0                umeng_app_score   0.0872713   -0.0482007
# 0                umeng_app_score   0.0872713    0.0748594
# 0                umeng_app_score   0.0872713     0.417455
# 0                umeng_app_score   0.0872713     0.113639
# 0                umeng_app_score   0.0872713      0.52506
# 0                umeng_app_score   0.0872713    0.0415219
# 0                yys_fakeCallNum   0.0833355    -0.303957
# 0                yys_fakeCallNum   0.0833355    -0.266405
# 0                yys_fakeCallNum   0.0833355     -0.29814
# 0                yys_fakeCallNum   0.0833355    -0.105029
# 0                yys_fakeCallNum   0.0833355    0.0687103
# 0                yys_fakeCallNum   0.0833355    -0.123025
# 0                yys_fakeCallNum   0.0833355    0.0945699
# 0                yys_fakeCallNum   0.0833355     0.192803
# 0                yys_fakeCallNum   0.0833355     0.368675
# 0      yys_specialCate4CalledNum   0.0832237    -0.193204
# 0      yys_specialCate4CalledNum   0.0832237    -0.249204
# 0      yys_specialCate4CalledNum   0.0832237    -0.135496
# 0      yys_specialCate4CalledNum   0.0832237     0.205992
# 0      yys_specialCate4CalledNum   0.0832237    0.0488403
# 0      yys_specialCate4CalledNum   0.0832237    -0.645744
# 0      yys_specialCate4CalledNum   0.0832237    -0.230329
# 0      yys_specialCate4CalledNum   0.0832237    -0.362243
# 0      yys_specialCate4CalledNum   0.0832237   -0.0845217
# 0      yys_specialCate4CalledNum   0.0832237    -0.180705
# 0      yys_specialCate4CalledNum   0.0832237     0.368675
# 0  yys_specialCate3CalledSeconds   0.0818557    -0.243975
# 0  yys_specialCate3CalledSeconds   0.0818557    0.0122949
# 0  yys_specialCate3CalledSeconds   0.0818557      0.29057
# 0  yys_specialCate3CalledSeconds   0.0818557     0.368675
# 0        yys_specialCate2CallNum   0.0813928    -0.218524
# 0        yys_specialCate2CallNum   0.0813928     0.412943
# 0        yys_specialCate2CallNum   0.0813928     0.368675
# 0        yys_specialCate6TalkNum   0.0797649   -0.0588875
# 0        yys_specialCate6TalkNum   0.0797649    -0.176597
# 0        yys_specialCate6TalkNum   0.0797649   -0.0201507
# 0        yys_specialCate6TalkNum   0.0797649    -0.310163
# 0        yys_specialCate6TalkNum   0.0797649   -0.0384224
# 0        yys_specialCate6TalkNum   0.0797649    -0.232625
# 0        yys_specialCate6TalkNum   0.0797649    -0.364634
# 0        yys_specialCate6TalkNum   0.0797649    0.0726579
# 0        yys_specialCate6TalkNum   0.0797649   -0.0350363
# 0        yys_specialCate6TalkNum   0.0797649    -0.377297
# 0        yys_specialCate6TalkNum   0.0797649     0.368675
# 0        yys_specialCate4CallNum   0.0786261    -0.351832
# 0        yys_specialCate4CallNum   0.0786261    -0.285569
# 0        yys_specialCate4CallNum   0.0786261    -0.123361
# 0        yys_specialCate4CallNum   0.0786261    -0.472576
# 0        yys_specialCate4CallNum   0.0786261    0.0209237
# 0        yys_specialCate4CallNum   0.0786261    -0.401828
# 0        yys_specialCate4CallNum   0.0786261    0.0938097
# 0        yys_specialCate4CallNum   0.0786261     0.368675
# 0  yys_specialCate2CalledSeconds   0.0781446    -0.230871
# 0  yys_specialCate2CalledSeconds   0.0781446     0.134061
# 0  yys_specialCate2CalledSeconds   0.0781446      0.26052
# 0  yys_specialCate2CalledSeconds   0.0781446     0.368675
# 0      yys_specialCate3CalledNum   0.0754949    -0.238554
# 0      yys_specialCate3CalledNum   0.0754949   0.00444675
# 0      yys_specialCate3CalledNum   0.0754949     0.152094
# 0      yys_specialCate3CalledNum   0.0754949     0.368675
# 0      yys_specialCate2CalledNum   0.0748466    -0.230296
# 0      yys_specialCate2CalledNum   0.0748466     0.037665
# 0      yys_specialCate2CalledNum   0.0748466     0.167134
# 0      yys_specialCate2CalledNum   0.0748466     0.368675
# 0        yys_specialCate5CallNum   0.0691061    -0.208447
# 0        yys_specialCate5CallNum   0.0691061    -0.121694
# 0        yys_specialCate5CallNum   0.0691061      0.13028
# 0        yys_specialCate5CallNum   0.0691061     0.368675
# 0  yys_specialCate5CalledSeconds   0.0685411    -0.187264
# 0  yys_specialCate5CalledSeconds   0.0685411    0.0954602
# 0  yys_specialCate5CalledSeconds   0.0685411     -0.39861
# 0  yys_specialCate5CalledSeconds   0.0685411   -0.0760879
# 0  yys_specialCate5CalledSeconds   0.0685411     0.368675
# 0      yys_specialCate5CalledNum   0.0635475    -0.179515
# 0      yys_specialCate5CalledNum   0.0635475    -0.172328
# 0      yys_specialCate5CalledNum   0.0635475   -0.0832903
# 0      yys_specialCate5CalledNum   0.0635475     0.368675
# 0           umeng_location_score   0.0392579   -0.0874214
# 0           umeng_location_score   0.0392579    -0.309569
# 0           umeng_location_score   0.0392579   0.00216729
# 0           umeng_location_score   0.0392579     0.302806
# 0           umeng_location_score   0.0392579    -0.158212
# 0           umeng_location_score   0.0392579    0.0531858
# 0           umeng_location_score   0.0392579    -0.241621
# 0           umeng_location_score   0.0392579   -0.0896432
# 0           umeng_location_score   0.0392579    -0.346335
# 0           umeng_location_score   0.0392579     0.435034
# 0           umeng_location_score   0.0392579     0.032997
# 0             umeng_credit_score   0.0314939     0.186947
# 0             umeng_credit_score   0.0314939   -0.0674216
# 0             umeng_credit_score   0.0314939    -0.276221
# 0             umeng_credit_score   0.0314939   -0.0053064
# 0             umeng_credit_score   0.0314939    -0.265791
# 0             umeng_credit_score   0.0314939     0.363958
# 0             umeng_credit_score   0.0314939    0.0210823
# 0             umeng_credit_score   0.0314939     0.254185
# 0             umeng_credit_score   0.0314939    -0.141738
# 0             umeng_credit_score   0.0314939     0.136026
# 0             umeng_credit_score   0.0314939    0.0501668
# 0             umeng_device_price   0.0289676     0.396522
# 0             umeng_device_price   0.0289676     0.113742
# 0             umeng_device_price   0.0289676    0.0270704
# 0             umeng_device_price   0.0289676   -0.0646238
# 0             umeng_device_price   0.0289676    -0.351456
# 0             umeng_device_price   0.0289676    0.0383656
# 0           umeng_interest_score   0.0279132    0.0337435
# 0           umeng_interest_score   0.0279132     0.150981
# 0           umeng_interest_score   0.0279132  0.000221481
# 0           umeng_interest_score   0.0279132     0.237378
# 0           umeng_interest_score   0.0279132     0.097693
# 0           umeng_interest_score   0.0279132    -0.216219
# 0           umeng_interest_score   0.0279132    -0.365821
# 0           umeng_interest_score   0.0279132     0.205992
# 0           umeng_interest_score   0.0279132    -0.046197
# 0           umeng_interest_score   0.0279132    -0.392902
# 0           umeng_interest_score   0.0279132    0.0678558
# 0             umeng_device_score   0.0258993     0.167785
# 0             umeng_device_score   0.0258993    -0.181228
# 0             umeng_device_score   0.0258993  -0.00573985
# 0             umeng_device_score   0.0258993     0.131133
# 0             umeng_device_score   0.0258993     -0.51156
# 0             umeng_device_score   0.0258993    -0.159503
# 0             umeng_device_score   0.0258993     0.330088
# 0             umeng_device_score   0.0258993     0.103847
# 0             umeng_device_score   0.0258993    -0.156854
# 0             umeng_device_score   0.0258993  -0.00300705
# 0             umeng_device_score   0.0258993    0.0514789
# 0              umeng_device_rank  0.00906109   -0.0869527
# 0              umeng_device_rank  0.00906109     0.122559
# 0              umeng_device_rank  0.00906109   -0.0816694
# 0              umeng_device_rank  0.00906109    0.0868974
# 0                 umeng_id_score  0.00553892    -0.108031
# 0                 umeng_id_score  0.00553892   -0.0576807
# 0                 umeng_id_score  0.00553892   -0.0158525
# 0                 umeng_id_score  0.00553892     0.138432
# 0                 umeng_id_score  0.00553892    -0.014175
# 0                 umeng_id_score  0.00553892    0.0350783
# 0              td_final_decision    0.265018     0.439491
# 0              td_final_decision    0.265018    -0.616559
# 0              td_final_decision    0.265018            0
# 0              yys_phoneLocation    0.127723    -0.284497
# 0              yys_phoneLocation    0.127723    -0.313721
# 0              yys_phoneLocation    0.127723    -0.236543
# 0              yys_phoneLocation    0.127723     0.097021
# 0              yys_phoneLocation    0.127723    -0.119651
# 0              yys_phoneLocation    0.127723    -0.461046
# 0              yys_phoneLocation    0.127723     0.361139
# 0              yys_phoneLocation    0.127723     0.458346
# 0              yys_phoneLocation    0.127723    -0.595884
# 0              yys_phoneLocation    0.127723     0.361139
# 0                  yys_friendMap    0.124963    -0.273447
# 0                  yys_friendMap    0.124963    -0.354136
# 0                  yys_friendMap    0.124963    0.0722986
# 0                  yys_friendMap    0.124963   -0.0768183
# 0                  yys_friendMap    0.124963    -0.509836
# 0                  yys_friendMap    0.124963    -0.221262
# 0                  yys_friendMap    0.124963     0.358017
# 0                  yys_friendMap    0.124963    -0.383491
# 0                  yys_friendMap    0.124963     0.463906
# 0                  yys_friendMap    0.124963     -0.60992
# 0                  yys_friendMap    0.124963     0.358017
# 0                     geo_A3_RSL   0.0276614   -0.0980506
# 0                     geo_A3_RSL   0.0276614     0.207525
# 0                     geo_A3_RSL   0.0276614     0.346209
# 0                     geo_A3_RSL   0.0276614   -0.0980506
# 0           14.37%  74.9925        5       5
# 0           21.65%  103.072      NaN     NaN
# 0           12.13%  102.698       -1      -1
# 0            8.18%  112.481      509     408
# 0            6.96%  100.018      527     510
# 0            4.95%  120.094      548     528
# 0            8.90%  107.956      572     549
# 0           10.23%  83.9541      590     573
# 0            4.25%  74.0879      594     591
# 0            4.98%  117.289      604     595
# 0           12.87%  96.3913      610     605
# 0            6.53%  72.4068      762     611
# 0           20.00%  105.479      NaN     NaN
# 0            4.95%  113.935      509     383
# 0            4.94%   86.406      528     510
# 0           15.53%  99.5463      589     529
# 0            5.19%  110.781      600     590
# 0            4.74%  65.4084      602     601
# 0            4.51%  87.9562      629     603
# 0            5.06%  128.636      635     630
# 0           11.81%  108.472      671     636
# 0           10.90%  88.1467      677     675
# 0           18.75%  99.7621      782     681
# 0           13.62%  104.137      NaN     NaN
# 0           39.78%  93.2893        0       0
# 0           21.39%  110.052        1       1
# 0           16.60%  93.6871        3       2
# 0           22.22%  107.055      NaN     NaN
# 0            6.76%   91.715      473     326
# 0           30.55%  95.5095      510     489
# 0           25.84%  98.7506      532     519
# 0           17.84%  111.404      829     533
# 0            7.97%  98.8822      850     846
# 0           11.03%  102.806      NaN     NaN
# 0           50.69%  139.199      NaN     NaN
# 0           49.31%   59.699      NaN     NaN
# 0            0.00%      NaN      NaN     NaN
# 0            6.92%  79.3282      NaN     NaN
# 0            9.59%  77.4116      NaN     NaN
# 0            8.50%  82.5553      NaN     NaN
# 0            6.88%    107.9      NaN     NaN
# 0           10.52%  90.8559      NaN     NaN
# 0            9.38%  68.3154      NaN     NaN
# 0            3.79%  126.132      NaN     NaN
# 0            5.51%   141.07      NaN     NaN
# 0           10.29%  60.7883      NaN     NaN
# 0           28.63%  132.303      NaN     NaN
# 0            6.29%  80.0627      NaN     NaN
# 0            8.09%   74.823      NaN     NaN
# 0            6.87%  105.846      NaN     NaN
# 0           11.57%  94.0535      NaN     NaN
# 0            9.78%  65.5058      NaN     NaN
# 0            7.18%  83.6053      NaN     NaN
# 0            3.62%  123.606      NaN     NaN
# 0            6.83%  72.9874      NaN     NaN
# 0            5.31%  141.625      NaN     NaN
# 0            5.84%   60.047      NaN     NaN
# 0           28.64%  132.254      NaN     NaN
# 0           74.97%   92.427      NaN     NaN
# 0           13.81%  117.425      NaN     NaN
# 0           10.86%   130.16      NaN     NaN
# 0            0.36%   98.901      NaN     NaN
# 0            6.27%  148.495      NaN     NaN
# 0            0.71%  64.5281      NaN     NaN
# 0           93.03%  97.0043      NaN     NaN
# 0           26.52%  83.1936      NaN     NaN
# 0           56.45%   105.73      NaN     NaN
# 0           17.03%  107.182      NaN     NaN
# 0            9.08%  81.7423      NaN     NaN
# 0           90.59%  101.631      NaN     NaN
# 0            0.33%   154.96      NaN     NaN

# %% [markdown]
# ## FEATURE TRANSFORMATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################5. FEATURE TRANSFORMATION#####################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Find the best transformation for each feature in the input dataframe
#--------------------------------------------------------------------------------------------------#
# : param drop_ori_feat: whether to drop original feature
# : params silent: whether to print details of transformation process
basic_transformr = FeatureTransformer(target=target, drop_features=True, silent=False, recoding_dict=rs.recoding_dict, feat_dict=rs.feat_dict)
#--------------------------------------------------------------------------------------------------#
# : param action: only take action when the param is True. Otherwise return origin values
# : param exclude_list: list of features excluded from being transformed when action is True
df_tr = basic_transformr.fit_transform(df_tr, label=label, fit_action=useTransformr, transform_action=useTransformr, exclude_list=exclude_list)
df_va = basic_transformr.transform(df_va, label=label, transform_action=useTransformr, exclude_list=exclude_list)
df_te = basic_transformr.transform(df_te, label=label, transform_action=useTransformr, exclude_list=exclude_list)
# Out:
# Best transformation for yys_specialCate6TalkNum is without transformation
# Best transformation for umeng_credit_score is square transformation
# Best transformation for yys_specialCate3CallNum is square transformation
# Best transformation for umeng_device_score is square transformation
# Best transformation for yys_specialCate5CalledSeconds is log transformation
# Best transformation for umeng_id_score is square transformation
# Best transformation for yys_monthlyAvgConsume is log transformation
# Best transformation for yys_fakeCallNum is log transformation
# Best transformation for td_final_score is log transformation
# Best transformation for yys_specialCate5CallNum is square transformation
# Best transformation for yys_specialCate2CalledSeconds is square transformation
# Best transformation for yys_specialCate2CalledNum is square transformation
# Best transformation for yys_specialCate7TalkNum is square transformation
# Best transformation for yys_specialCate3CalledSeconds is square transformation
# Best transformation for umeng_device_price is log transformation
# Best transformation for umeng_device_rank is square transformation
# Best transformation for umeng_location_score is log transformation
# Best transformation for yys_specialCate4CalledSeconds is square transformation
# Best transformation for yys_specialCate3CalledNum is square transformation
# Best transformation for yys_specialCate5CalledNum is square transformation
# Best transformation for riskScore is square transformation
# Best transformation for umeng_interest_score is log transformation
# Best transformation for yys_specialCate4CalledNum is square transformation
# Best transformation for yys_specialCate4CallNum is without transformation
# Best transformation for umeng_app_score is log transformation
# Best transformation for yys_specialCate2CallNum is square transformation

# %% [markdown]
# ## FEATURE TRIMMING

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################  6. FEATURE TRIMMING   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Trim continuous variables in the dataframe
#--------------------------------------------------------------------------------------------------#
# : params silent: whether to print details of transformation process
trimmr = FeatureTrimmer(target=target, silent=False, recoding_dict=rs.recoding_dict, feat_dict=rs.feat_dict)
#--------------------------------------------------------------------------------------------------#
# : param action: only take action when the param is True. Otherwise return origin values
# : param exclude_list: list of features excluded from being trimmed
df_tr = trimmr.fit_transform(df_tr, action=useTrimmr, exclude_list=exclude_list)
df_va = trimmr.transform(df_va, label=label, action=useTrimmr, exclude_list=exclude_list)
df_te = trimmr.transform(df_te, label=label, action=useTrimmr, exclude_list=exclude_list)
# Out:
# Trim continuous features in the dataframe

# %% [markdown]
# ## FEATURE ENCODING

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################   7. FEATURE ENCODING  ######################################
######################################                        ######################################
####################################################################################################

# Try to recode each feature in the dataframe
#--------------------------------------------------------------------------------------------------#
# detect features of type object
df_tr.select_dtypes(include=[object]).head()
# Out:
#                    docid   loan_date td_final_decision baidu_risk_blacklevel  \
# 6531  370321197207303337  2018-07-23            Accept                   NaN
# 6116  362222197901310511  2018-07-19            Accept                   NaN
# 749   532725198005162111  2018-07-25            Accept                   NaN
# 2110  513435197310300030  2018-06-26            Accept                   NaN
# 303   450122197704086017  2018-06-05            Review                   NaN
#
#      umeng_device_os yys_friendMap yys_phoneLocation geo_A3_RSL geo_B7_RSL
# 6531         android            山东                山东      \3\""      \1\""
# 6116             NaN            广东                江西      \3\""      \0\""
# 749          android            云南                云南      \3\""      \0\""
# 2110         android           NaN               NaN      \3\""      \0\""
# 303          android           NaN               NaN      \3\""      \1\""

# %%
# : params target: list of boolean targets
# : param useWoeEncoder: whether to use woe encoder for every feature
# : param we_cut_method: choose cut method for woe encoder
# : param be_cut_method: choose cut method for bin encoder
# : param drop_ori_feat: whether to drop original feature
encodr = FeatureEncoder(target=target, use_woe_encoder=useWoeEncoder, drop_features=True,
                        we_cut_method='qcut', be_cut_method='qcut', recoding_dict=rs.recoding_dict, feat_dict=rs.feat_dict)
#--------------------------------------------------------------------------------------------------#
# : param WoeEncoder_feat: list of features manually chosen to apply woe encoder
# : param BinEncoder_feat: list of features manually chosen to apply bin encoder
# : param CountEncoder_feat: list of features manually chosen to apply count encoder
# : param OneHotEncoder_feat: list of features manually chosen to apply onehot encoder
# : param TargetEncoder_feat: list of features manually chosen to apply onehot encoder
# : param NaEncoder_feat: list of features manually chosen to apply na encoder
# : param exclude_list: list of features kept the same
df_tr = encodr.fit_transform(df_tr, label
                            , WoeEncoder_feat=[
                                               'yys_fakeCallNum_log'
                                              ,'yys_specialCate3CalledNum_square'
                                              ,'yys_specialCate5CalledNum_square'
                                              ,'yys_specialCate4CalledSeconds_square'
                                              , 'yys_specialCate5CalledSeconds_log'
                                              , 'yys_specialCate3CallNum_square'
                                              , 'yys_specialCate4CalledNum_square']
                            , BinEncoder_feat=[
                                               'umeng_credit_score_square'
                                              ,'umeng_device_price_log'
                                              ,'umeng_device_score_square'
                                              ,'umeng_id_score_square'
                                              ,'umeng_interest_score_log'
                                              ,'umeng_location_score_log']
                            , CountEncoder_feat=[
                                               'td_final_score_log']
                            , OneHotEncoder_feat=[
                                                'td_final_decision']
                            , TargetEncoder_feat=[
                                                 'yys_friendMap']
                            , NaEncoder_feat=[
                                            'geo_B7_RSL']
                            , exclude_list=exclude_list)

df_va = encodr.transform(df_va, label, exclude_list=exclude_list)
df_te = encodr.transform(df_te, label, exclude_list=exclude_list)
# Out:
# Apply WoeEncoder to encode yys_specialCate6TalkNum
# Apply WoeEncoder to encode yys_specialCate2CalledSeconds_square
# Apply WoeEncoder to encode umeng_device_os
# Apply WoeEncoder to encode yys_specialCate2CallNum_square
# Apply WoeEncoder to encode yys_specialCate2CalledNum_square
# Apply WoeEncoder to encode baidu_risk_blacklevel
# Apply WoeEncoder to encode yys_phoneLocation
# Apply WoeEncoder to encode umeng_app_score_log
# Apply WoeEncoder to encode geo_A3_RSL
# Apply WoeEncoder to encode riskScore_square
# Apply WoeEncoder to encode yys_specialCate7TalkNum_square
# Apply WoeEncoder to encode yys_monthlyAvgConsume_log
# Apply WoeEncoder to encode yys_specialCate3CalledSeconds_square
# Apply WoeEncoder to encode yys_specialCate4CallNum
# Apply WoeEncoder to encode yys_specialCate5CallNum_square
# Apply WoeEncoder to encode umeng_device_rank_square
# Apply WoeEncoder to encode yys_fakeCallNum_log
# Apply WoeEncoder to encode yys_specialCate3CalledNum_square
# Apply WoeEncoder to encode yys_specialCate5CalledNum_square
# Apply WoeEncoder to encode yys_specialCate4CalledSeconds_square
# Apply WoeEncoder to encode yys_specialCate5CalledSeconds_log
# Apply WoeEncoder to encode yys_specialCate3CallNum_square
# Apply WoeEncoder to encode yys_specialCate4CalledNum_square
# Apply BinEncoder to encode umeng_credit_score_square
# Apply BinEncoder to encode umeng_device_price_log
# Apply BinEncoder to encode umeng_device_score_square
# Apply BinEncoder to encode umeng_id_score_square
# Apply BinEncoder to encode umeng_interest_score_log
# Apply BinEncoder to encode umeng_location_score_log
# Apply CountEncoder to encode td_final_score_log
# Apply OneHotEncoder to encode td_final_decision
# Apply TargetEncoder to encode yys_friendMap
# Apply NaEncoder to encode geo_B7_RSL

# %% [markdown]
# ## FEATURE IMPUTATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
###################################### 8. FEATURE IMPUTATION  ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Imputes features seperately using defined imputation strategy
#--------------------------------------------------------------------------------------------------#
# detect features with missing values
tmp = pd.concat([df_tr, df_va, df_te]).isnull().sum()
tmp[tmp != 0]
# Out:
# umeng_credit_score_square_be    1099
# umeng_device_score_square_be    1287
# umeng_location_score_log_be     1259
# umeng_interest_score_log_be     1890
# umeng_id_score_square_be        1042
# umeng_device_price_log_be       2046
# dtype: int64

# %%
# : params use_mean_method: whether use mean value to impute in default
# : params target: list of boolean targets
# : params silent: whether to print details of imputation process
imputr = FeatureImputer(use_mean_method=True, target=target, silent=False, recoding_dict=rs.recoding_dict, feat_dict=rs.feat_dict)
#--------------------------------------------------------------------------------------------------#
# : param action: only take action when the param is True. Otherwise return origin values
# : param mean_list: list of features to be imputed using mean value
# : param median_list: list of features to be imputed using median value
# : param most_freq_list: list of features to be imputed using most frequent value
# : param exclude_list: list of features kept the same
df_tr = imputr.fit_transform(df_tr, label, action=useImputr,
                             mean_list=[],
                             median_list=[],
                             most_freq_list=[],
                             exclude_list=exclude_list)

df_va = imputr.transform(df_va, label, action=useImputr, exclude_list=exclude_list)
df_te = imputr.transform(df_te, label, action=useImputr, exclude_list=exclude_list)

# %% [markdown]
# ## FEATURE SCALING

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################   9. FEATURE SCALING   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Scaler features in the dataframe
#--------------------------------------------------------------------------------------------------#
# : params silent: whether to print details of transformation process
# : params scaler_type: choose scaler's type, including StandardScaler and MinMaxScaler
scalr = FeatureScaler(target=target, silent=False, scaler_type='StandardScaler', recoding_dict=rs.recoding_dict, feat_dict=rs.feat_dict)
#--------------------------------------------------------------------------------------------------#
# : param action: only take action when the param is True. Otherwise return origin values
# : param exclude_list: list of features excluded from being trimmed
df_tr = scalr.fit_transform(df_tr, label=label, action=useScalr, exclude_list=exclude_list+encodr.final_OneHotEncoder_new_feat)
df_va = scalr.transform(df_va, label=label, action=useScalr, exclude_list=exclude_list+encodr.final_OneHotEncoder_new_feat)
df_te = scalr.transform(df_te, label=label, action=useScalr, exclude_list=exclude_list+encodr.final_OneHotEncoder_new_feat)
# Out:
# Use StandardScaler to scale the features

# %% [markdown]
# ## OUTPUT RECODING STATEMENT

# %%
rs.write_recoding_txt(file_name=ud_recoding_file, encoding = "utf-8" )

# recoding online data using the output recoding statement
df_ol = rs.exec_recoding(df_ol)
df_ol.head()
# Out:
#                 docid  riskScore   loan_date  td_final_score  \
# 0  413024198009031011       -3.0  2018-05-24              18
# 1  230404198009040524       -2.0  2018-07-02               6
#
#   td_final_decision baidu_risk_blacklevel  umeng_credit_score  \
# 0            Accept                 <NA>*               547.0
# 1            Accept                 <NA>*               577.0
#
#    umeng_device_price  umeng_device_score umeng_device_os  umeng_device_rank  \
# 0                 5.0               656.0             ios                0.0
# 1                 3.0               681.0         android                0.0
#
#    umeng_id_score  umeng_interest_score  umeng_location_score  \
# 0           510.0                 566.0                 578.0
# 1           532.0                 611.0                 588.0
#
#    umeng_app_score  yys_fakeCallNum  yys_monthlyAvgConsume  \
# 0            535.0              0.0                 166.84
# 1            535.0              NaN                    NaN
#
#    yys_specialCate3CallNum  yys_specialCate3CalledNum  \
# 0                      0.0                        0.0
# 1                      NaN                        NaN
#
#    yys_specialCate3CalledSeconds  yys_specialCate2CallNum  \
# 0                            0.0                      0.0
# 1                            NaN                      NaN
#
#    yys_specialCate2CalledNum  yys_specialCate2CalledSeconds  \
# 0                        0.0                            0.0
# 1                        NaN                            NaN
#
#    yys_specialCate5CallNum  yys_specialCate5CalledNum  \
# 0                      0.0                        0.0
# 1                      NaN                        NaN
#
#    yys_specialCate5CalledSeconds  yys_specialCate7TalkNum  \
# 0                            0.0                      0.0
# 1                            NaN                      NaN
#
#    yys_specialCate6TalkNum  yys_specialCate4CallNum  \
# 0                      9.0                      1.0
# 1                      NaN                      NaN
#
#    yys_specialCate4CalledNum  yys_specialCate4CalledSeconds yys_friendMap  \
# 0                        8.0                         1455.0            河南
# 1                        NaN                            NaN         <NA>*
#
#   yys_phoneLocation geo_A3_RSL geo_B7_RSL  label  umeng_credit_score_square  \
# 0                河南      \3\""      \0\""      0                   299209.0
# 1             <NA>*      \3\""      \0\""      0                   332929.0
#
#    umeng_credit_score_square_we  umeng_device_os_we  yys_phoneLocation_we  \
# 0                     -1.598779           -1.664277             -0.508312
# 1                      0.867370            0.679358              0.898793
#
#    yys_monthlyAvgConsume_log  yys_monthlyAvgConsume_log_we  \
# 0                   5.117035                     -0.694263
# 1                        NaN                      1.257748
#
#    td_final_score_log  td_final_score_log_we  yys_specialCate5CallNum_square  \
# 0            2.890372              -0.007723                             0.0
# 1            1.791759              -1.369700                             NaN
#
#    yys_specialCate5CallNum_square_we  yys_specialCate2CalledSeconds_square  \
# 0                          -0.764825                                   0.0
# 1                           1.357843                                   NaN
#
#    yys_specialCate2CalledSeconds_square_we  yys_specialCate2CalledNum_square  \
# 0                                -0.784036                               0.0
# 1                                 1.357910                               NaN
#
#    yys_specialCate2CalledNum_square_we  yys_specialCate7TalkNum_square  \
# 0                            -0.768373                             0.0
# 1                             1.394318                             NaN
#
#    yys_specialCate7TalkNum_square_we  umeng_device_price_square  \
# 0                          -1.343872                       25.0
# 1                           1.099984                        9.0
#
#    umeng_device_price_square_we  baidu_risk_blacklevel_we  \
# 0                     -2.102782                 -0.257407
# 1                     -0.347948                 -0.257407
#
#    yys_specialCate3CalledNum_square  yys_specialCate3CalledNum_square_we  \
# 0                               0.0                            -0.753036
# 1                               NaN                             1.384702
#
#    yys_specialCate5CalledNum_square  yys_specialCate5CalledNum_square_we  \
# 0                               0.0                            -0.716132
# 1                               NaN                             1.437266
#
#    riskScore_square  riskScore_square_we  geo_B7_RSL_we  \
# 0               9.0             1.793228       0.316025
# 1               4.0            -0.255258       0.316025
#
#    yys_specialCate4CalledNum_log  yys_specialCate4CalledNum_log_we  \
# 0                       2.079442                          0.478112
# 1                            NaN                          1.474886
#
#    yys_specialCate4CallNum_sqrt  yys_specialCate4CallNum_sqrt_we  \
# 0                           1.0                        -1.029684
# 1                           NaN                         1.511050
#
#    yys_specialCate2CallNum_square  yys_specialCate2CallNum_square_we  \
# 0                             0.0                          -0.683022
# 1                             NaN                           1.464082
#
#    yys_specialCate6TalkNum_we  yys_specialCate3CallNum_square  \
# 0                   -1.396311                             0.0
# 1                    1.348271                             NaN
#
#    yys_specialCate3CallNum_square_we  umeng_device_score_square  \
# 0                          -0.737564                   430336.0
# 1                           1.126862                   463761.0
#
#    umeng_device_score_square_we  yys_specialCate5CalledSeconds_log  \
# 0                     -0.599877                         -11.512925
# 1                     -0.931133                                NaN
#
#    yys_specialCate5CalledSeconds_log_we  umeng_id_score_square  \
# 0                             -0.768616               260100.0
# 1                              1.444902               283024.0
#
#    umeng_id_score_square_we  yys_fakeCallNum_square  \
# 0                 -0.205997                     0.0
# 1                  1.913635                     NaN
#
#    yys_fakeCallNum_square_we  yys_friendMap_we  \
# 0                  -0.955169         -0.886056
# 1                   1.385405          1.104598
#
#    yys_specialCate3CalledSeconds_square  \
# 0                                   0.0
# 1                                   NaN
#
#    yys_specialCate3CalledSeconds_square_we  umeng_device_rank_square  \
# 0                                -0.783856                       0.0
# 1                                 1.359576                       0.0
#
#    umeng_device_rank_square_we  umeng_location_score_log  \
# 0                    -0.408148                  6.359574
# 1                    -0.408148                  6.376727
#
#    umeng_location_score_log_we  geo_A3_RSL_we  \
# 0                     0.625698      -0.542064
# 1                    -0.848922      -0.542064
#
#    yys_specialCate4CalledSeconds_log  yys_specialCate4CalledSeconds_log_we  \
# 0                           7.282761                             -0.430561
# 1                                NaN                              1.510607
#
#    umeng_interest_score_log  umeng_interest_score_log_we  \
# 0                  6.338594                     0.754182
# 1                  6.415097                    -1.836859
#
#    td_final_decision_we  umeng_app_score_log  umeng_app_score_log_we  \
# 0             -1.013961             6.282267               -0.995021
# 1             -1.013961             6.282267               -0.995021
#
#    umeng_credit_score_square_be  td_final_score_log_ce  \
# 0                      0.045255              -0.122126
# 1                      1.770547               2.249889
#
#    umeng_device_price_log  umeng_device_price_log_be  geo_B7_RSL_ne  \
# 0                1.609438                   1.773369      -0.060348
# 1                1.098612                  -0.342800      -0.060348
#
#    yys_specialCate4CalledNum_square  yys_specialCate4CalledNum_square_we  \
# 0                              64.0                             0.913447
# 1                               NaN                             1.285372
#
#    yys_specialCate4CallNum_we  umeng_device_score_square_be  \
# 0                   -1.235496                      0.664915
# 1                    1.328497                      1.447111
#
#    umeng_id_score_square_be  yys_fakeCallNum_log  yys_fakeCallNum_log_we  \
# 0                  0.029750           -11.512925               -0.961630
# 1                  1.090838                  NaN                1.245794
#
#    yys_friendMap_te  umeng_location_score_log_be  \
# 0          -0.93182                    -0.898868
# 1           0.93723                    -0.527852
#
#    yys_specialCate4CalledSeconds_square  \
# 0                             2117025.0
# 1                                   NaN
#
#    yys_specialCate4CalledSeconds_square_we  umeng_interest_score_log_be  \
# 0                                -0.007065                    -0.163232
# 1                                 1.275981                     1.653925
#
#    td_final_decision_Accept  td_final_decision_Review
# 0                         1                         0
# 1                         1                         0

# %% [markdown]
# ## FEATURE SELECTION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
###################################### 10. FEATURE SELECTION  ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

# Filter features by IV and model's feature importance
#--------------------------------------------------------------------------------------------------#
# : params exclude_list: columns to be excluded
# : params drop_weak: whether to drop features with iv below iv_floor
# : params drop_suspicous: whether to drop features with iv beyond iv_cap
# : params silent: whether to print details of filtering process
ffiltr = FeatureFilter(target=target, exclude_list=exclude_list, drop_weak=True, drop_suspicous=True, silent=False)
#--------------------------------------------------------------------------------------------------#
if useIvFiltr:
    print_stype_line();
    print('IV FILTER IS FILTERING FEATURES');
    print_stype_line()
    # : params iv_floor: minimum of acceptable iv
    # : params iv_cap: maximum of acceptable iv
    # : params trimmr: trimmer used to trim continuous variables
    # : params cav_list_appd: extra categorical variables to be added
    # : params cov_list_appd: extra cotinuous variables to be added
    # : params bins: number of bins
    # : param woe_min: minimum of woe value
    # : param woe_max: maximum of woe value
    df_tr = ffiltr.iv_filter_fit_transform(df_tr, cov_appd_list=[], cav_appd_list=[], iv_floor=0.02, iv_cap=1,
                                              trimmr=None, bins=10, woe_min=-20, woe_max=20)
    df_va = ffiltr.iv_filter_transform(df_va)
    df_te = ffiltr.iv_filter_transform(df_te)
    df_ol = ffiltr.iv_filter_transform(df_ol)
#--------------------------------------------------------------------------------------------------#
if useXgbfiFiltr:
    print_stype_line();
    print('FEATURE IMPORTANCE FILTER BASED ON XGBOOST MODEL IS FILTERING FEATURES');
    print_stype_line()
    # : params xgb_params: parameters for training xgb model
    # : params alpha: weight parameter for importance_type 
    #                 (larger the alpha, larger the weight for importance_type = gain)
    # : params top: number of features from each importance_type to keep when method is 'interaction' and 
    #               number of features to keep in total when method is 'rank'
    # : params random_state: seed
    df_tr = ffiltr.xgbFI_filter_fit_transform(df_tr, label, None, xgb_params=XGB_PARAMS, alpha=0.7, top=xgb_feat_cnt,
                                                 random_state=2019)
    df_va = ffiltr.xgbFI_filter_transform(df_va, label)
    df_te = ffiltr.xgbFI_filter_transform(df_te, label)
    df_ol = ffiltr.xgbFI_filter_transform(df_ol, label)
    ffiltr.xgb_fi.head(20)
#--------------------------------------------------------------------------------------------------#
if useRFfiFiltr:
    print_stype_line();
    print('FEATURE IMPORTANCE FILTER BASED ON RANDOMFOREST MODEL IS FILTERING FEATURES');
    print_stype_line()
    # : params top: number of features to keep
    df_tr = ffiltr.rfFI_filter_fit_transform(df_tr, label, top=rf_feat_cnt)
    df_va = ffiltr.rfFI_filter_transform(df_va, label)
    df_te = ffiltr.rfFI_filter_transform(df_te, label)
    df_ol = ffiltr.rfFI_filter_transform(df_ol, label)
    ffiltr.rf_fi.head(15)
#--------------------------------------------------------------------------------------------------#
if useLRFiltr:
    print_stype_line();
    print('FEATURE IMPORTANCE FILTER BASED ON LOGISTIC REGRESSION MODEL IS FILTERING FEATURES');
    print_stype_line()
    # : params feat_cnt: number of features to keep at most
    # : params alpha: significant level (p value) for model selection
    # : params stepwise: whether to use bidirectional stepwise selection        
    df_tr = ffiltr.lr_filter_fit_transform(df_tr, label, feat_cnt=lr_feat_cnt, alpha=0.05, stepwise=True)
    df_va = ffiltr.lr_filter_transform(df_va, label)
    df_te = ffiltr.lr_filter_transform(df_te, label)
    df_ol = ffiltr.lr_filter_transform(df_ol, label)
# Out:
# ########################################################################################################################
# ########################################################################################################################
#
# IV FILTER IS FILTERING FEATURES
#
# ########################################################################################################################
# ########################################################################################################################
#
# Features shown as below should be dropped
#
#                               iv_for_label
# umeng_credit_score_square_be         0.016
# umeng_interest_score_log_be          0.016
# umeng_device_score_square_be         0.007
# umeng_id_score_square_be             0.004
# umeng_device_rank_square_we          0.001
# geo_B7_RSL_ne                        0.000
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# These features are weak, cuz their IVs do not exceed defined floor: 0.02
#
#  umeng_credit_score_square_be
#  umeng_interest_score_log_be
#  umeng_device_score_square_be
#  umeng_id_score_square_be
#  umeng_device_rank_square_we
#  geo_B7_RSL_ne
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# These features are suspicous, cuz their IVs exceed defined cap: 1
#
#
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Remaining important features are shown as below:
#
#                                     iv_for_label
# td_final_score_log_ce                     0.279
# td_final_decision_Accept_oe               0.262
# td_final_decision_Review_oe               0.262
# yys_phoneLocation_we                      0.115
# yys_friendMap_te                          0.111
# yys_specialCate7TalkNum_square_we         0.074
# umeng_app_score_log_we                    0.071
# yys_specialCate3CallNum_square_we         0.071
# yys_fakeCallNum_log_we                    0.058
# yys_monthlyAvgConsume_log_we              0.057
#
# ########################################################################################################################
# ########################################################################################################################
#
# FEATURE IMPORTANCE FILTER BASED ON XGBOOST MODEL IS FILTERING FEATURES
#
# ########################################################################################################################
# ########################################################################################################################
#
# Features shown as are important according to XGBoost model's feature importance ranking
#                                          weight  weight_rank       gain  \
# td_final_score_log_ce                       293            1  24.771167
# yys_phoneLocation_we                        167            2  22.429538
# td_final_decision_Review_oe                 101            9  85.272443
# yys_friendMap_te                            163            3  21.697434
# td_final_decision_Accept_oe                  63           14  79.700949
# umeng_app_score_log_we                      160            4  16.596222
# yys_specialCate7TalkNum_square_we           118            7  18.524289
# geo_A3_RSL_we                               120            6  15.203747
# umeng_device_price_log_be                   128            5  14.841396
# umeng_device_os_we                           93           10  14.073914
# yys_specialCate4CalledNum_square_we         108            8  11.862799
# yys_specialCate4CalledSeconds_square_we      69           12  11.934113
# yys_specialCate3CallNum_square_we            46           18  12.898180
# yys_specialCate5CalledSeconds_log_we         25           21  13.591277
# yys_fakeCallNum_log_we                       49           17  11.534021
# yys_specialCate6TalkNum_we                   77           11  10.108573
# yys_monthlyAvgConsume_log_we                 59           16  11.280729
# riskScore_square_we                          61           15  10.320593
# yys_specialCate3CalledNum_square_we           7           23  11.741170
# umeng_location_score_log_be                  66           13   7.478225
#
#                                          gain_rank  rank
# td_final_score_log_ce                            3   2.4
# yys_phoneLocation_we                             4   3.4
# td_final_decision_Review_oe                      1   3.4
# yys_friendMap_te                                 5   4.4
# td_final_decision_Accept_oe                      2   5.6
# umeng_app_score_log_we                           7   6.1
# yys_specialCate7TalkNum_square_we                6   6.3
# geo_A3_RSL_we                                    8   7.4
# umeng_device_price_log_be                        9   7.8
# umeng_device_os_we                              10  10.0
# yys_specialCate4CalledNum_square_we             14  12.2
# yys_specialCate4CalledSeconds_square_we         13  12.7
# yys_specialCate3CallNum_square_we               12  13.8
# yys_specialCate5CalledSeconds_log_we            11  14.0
# yys_fakeCallNum_log_we                          16  16.3
# yys_specialCate6TalkNum_we                      19  16.6
# yys_monthlyAvgConsume_log_we                    17  16.7
# riskScore_square_we                             18  17.1
# yys_specialCate3CalledNum_square_we             15  17.4
# umeng_location_score_log_be                     23  20.0
# ########################################################################################################################
# ########################################################################################################################
#
# FEATURE IMPORTANCE FILTER BASED ON RANDOMFOREST MODEL IS FILTERING FEATURES
#
# ########################################################################################################################
# ########################################################################################################################
#
# Features shown as are important according to RandomForest model's feature importance ranking
#                                          feature importance
# td_final_decision_Review_oe                        0.288307
# td_final_decision_Accept_oe                        0.216743
# td_final_score_log_ce                              0.143649
# yys_phoneLocation_we                               0.085769
# yys_friendMap_te                                   0.072773
# umeng_app_score_log_we                             0.041582
# yys_specialCate7TalkNum_square_we                  0.023224
# yys_specialCate3CallNum_square_we                  0.021515
# yys_specialCate4CalledSeconds_square_we            0.014447
# yys_fakeCallNum_log_we                             0.012510
# geo_A3_RSL_we                                      0.010327
# umeng_device_price_log_be                          0.009563
# yys_monthlyAvgConsume_log_we                       0.009147
# yys_specialCate4CalledNum_square_we                0.008483
# yys_specialCate6TalkNum_we                         0.007922
# ########################################################################################################################
# ########################################################################################################################
#
# FEATURE IMPORTANCE FILTER BASED ON LOGISTIC REGRESSION MODEL IS FILTERING FEATURES
#
# ########################################################################################################################
# ########################################################################################################################
#
# yys_friendMap_te enters: p-value = 0.0
# td_final_decision_Accept_oe enters: p-value = 0.0
# td_final_decision_Review_oe enters: p-value = 0.0
# umeng_app_score_log_we enters: p-value = 0.0
# geo_A3_RSL_we enters: p-value = 0.0
# td_final_score_log_ce enters: p-value = 0.0
# umeng_device_price_log_be enters: p-value = 0.0
# yys_specialCate3CallNum_square_we enters: p-value = 0.0002
# baidu_risk_blacklevel_we enters: p-value = 0.0007
# yys_specialCate5CalledSeconds_log_we enters: p-value = 0.0111
# yys_specialCate7TalkNum_square_we enters: p-value = 0.0
# yys_monthlyAvgConsume_log_we enters: p-value = 0.0052
# yys_specialCate4CalledSeconds_square_we enters: p-value = 0.0058
# yys_specialCate6TalkNum_we enters: p-value = 0.0102
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Features selected by Logistic Regression Model are shown as below:
#
#  yys_friendMap_te
#  td_final_decision_Accept_oe
#  td_final_decision_Review_oe
#  umeng_app_score_log_we
#  geo_A3_RSL_we
#  td_final_score_log_ce
#  umeng_device_price_log_be
#  yys_specialCate3CallNum_square_we
#  baidu_risk_blacklevel_we
#  yys_specialCate5CalledSeconds_log_we
#  yys_specialCate7TalkNum_square_we
#  yys_monthlyAvgConsume_log_we
#  yys_specialCate4CalledSeconds_square_we
#  yys_specialCate6TalkNum_we

# %% [markdown]
# ## FEATURE EVALUATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################11. FEATURE EVALUATION  ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

print_stype_line();
print('FEATURE EXPLORATION MODULE IS PROCESSING');
print_stype_line()

# Calculate vifs and correlations of columns in the dataframe
df = pd.concat([df_tr, df_va, df_te], axis=0)
vif, _ = get_vif_cor(df, target, plot=True)

print('\n' + '_ ' * 60 + ' ');
print("Vif of features")
print(vif)
#--------------------------------------------------------------------------------------------------#
print('\n' + '_ ' * 60 + ' ');
print("plot histograms of features")

# : params bins: number of bins
plot_hist_all(df, target=['label'], extr_outlier_removed=False)
# Out:
# ########################################################################################################################
# ########################################################################################################################
#
# FEATURE EXPLORATION MODULE IS PROCESSING
#
# ########################################################################################################################
# ########################################################################################################################
#
# Correlation map of features
#
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Vif of features
#                                             vif
# td_final_decision_Review_oe                 inf
# td_final_decision_Accept_oe                 inf
# yys_specialCate5CalledSeconds_log_we     11.417
# yys_specialCate6TalkNum_we                5.156
# yys_specialCate4CalledSeconds_square_we   3.596
# yys_monthlyAvgConsume_log_we              3.559
# yys_specialCate3CallNum_square_we         2.339
# yys_specialCate7TalkNum_square_we         2.243
# yys_friendMap_te                          1.627
# td_final_score_log_ce                     1.626
# umeng_app_score_log_we                    1.047
# umeng_device_price_log_be                 1.029
# baidu_risk_blacklevel_we                  1.018
# geo_A3_RSL_we                             1.017
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# plot histograms of features

# %% [markdown]
# ## MODEL TRAINING

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################   12. MODEL TRAINING   ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################
# columns used to train models
col = [i for i in df_tr.columns if i not in [label] + exclude_list + target]

x = pd.concat([df_tr[col], df_va[col], df_te[col]], axis=0)
y = pd.concat([df_tr[label], df_va[label], df_te[label]], axis=0)

# %%
print_stype_line();print('MODEL SELECTION MODULE IS PROCESSING');print_stype_line()
best_model, best_model_params, score_dict, params_dict = model_selection(x, y, init_points=5, n_iter=10, acq='ei', cv=5,
                                                                         random_state=2019)
# Out:
# ########################################################################################################################
# ########################################################################################################################
#
# MODEL SELECTION MODULE IS PROCESSING
#
# ########################################################################################################################
# ########################################################################################################################
#
# Apply bayesian optimization to XGBoost model
#
# |   iter    |  target   |   alpha   | colsam... |    eta    |   gamma   |  lambdA   | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        |  0.692    |  12.09    |  0.3774   |  0.4972   |  0.151    |  56.87    |  11.19    |  1.655    |  0.8507   |
# |  2        |  0.6779   |  51.0     |  0.2493   |  0.3564   |  0.2653   |  44.98    |  3.654    |  5.65     |  0.2692   |
# |  3        |  0.6735   |  4.212    |  0.2971   |  0.4233   |  0.5596   |  0.02269  |  6.2      |  9.709    |  0.04587  |
# |  4        |  0.6868   |  48.68    |  0.5602   |  0.4971   |  0.8627   |  57.48    |  6.651    |  19.0     |  0.4218   |
# |  5        |  0.6841   |  55.95    |  0.3053   |  0.1806   |  0.3919   |  23.37    |  9.609    |  10.72    |  0.451    |
# |  6        |  0.6953   |  0.0      |  0.9      |  0.001    |  0.0      |  100.0    |  15.0     |  19.0     |  0.9      |
# |  7        |  0.6642   |  98.09    |  0.6589   |  0.4287   |  0.904    |  99.43    |  15.0     |  10.19    |  0.3262   |
# |  8        |  0.6975   |  9.973    |  0.7228   |  0.00879  |  0.08223  |  56.37    |  14.94    |  18.66    |  0.7578   |
# |  9        |  0.6943   |  9.029    |  0.7749   |  0.256    |  0.7994   |  69.47    |  14.82    |  18.93    |  0.6088   |
# |  10       |  0.693    |  44.37    |  0.3878   |  0.4259   |  0.008742 |  53.47    |  14.78    |  18.67    |  0.8692   |
# |  11       |  0.6553   |  99.51    |  0.04275  |  0.3488   |  0.1083   |  7.345    |  14.68    |  18.07    |  0.2453   |
# |  12       |  0.6923   |  8.594    |  0.7781   |  0.1174   |  0.02325  |  99.15    |  14.35    |  1.774    |  0.2945   |
# |  13       |  0.6952   |  19.31    |  0.8979   |  0.3715   |  0.8593   |  35.02    |  14.7     |  17.4     |  0.7436   |
# |  14       |  0.6652   |  26.3     |  0.0808   |  0.01147  |  0.7934   |  99.15    |  13.56    |  18.41    |  0.7069   |
# |  15       |  0.6644   |  0.3836   |  0.4475   |  0.143    |  0.04029  |  83.25    |  14.34    |  1.056    |  0.5124   |
# =========================================================================================================================
# Best combination of parameters are shownn as below
#  {'objective': 'reg:linear', 'eval_metric': 'rmse', 'min_child_weight': 18, 'eta': 0.008789627886968451, 'max_depth': 14, 'subsample': 0.7577650135350398, 'colsample_bytree': 0.7227768608118904, 'gamma': 0.0822324478988421, 'lambdA': 56.371020883052914, 'alpha': 9.972959760972078}
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Apply bayesian optimization to RandomForest model
#
# |   iter    |  target   | max_depth | max_fe... | min_sa... | min_sa... | n_esti... |
# -------------------------------------------------------------------------------------
# |  1        |  0.6866   |  10.91    |  0.1121   |  0.03729  |  14.09    |  184.9    |
# |  2        |  0.6805   |  23.33    |  0.1826   |  0.1217   |  6.827    |  699.3    |
# |  3        |  0.6404   |  15.23    |  0.9233   |  0.2561   |  26.95    |  852.7    |
# |  4        |  0.6788   |  2.761    |  0.3953   |  0.08018  |  14.13    |  510.5    |
# |  5        |  0.5      |  27.5     |  0.2758   |  0.4787   |  7.215    |  687.3    |
# |  6        |  0.6681   |  1.0      |  0.1      |  0.01     |  2.0      |  760.4    |
# |  7        |  0.6304   |  1.0      |  0.999    |  0.01     |  40.0     |  363.4    |
# |  8        |  0.5      |  40.0     |  0.999    |  0.5      |  40.0     |  10.0     |
# |  9        |  0.6989   |  40.0     |  0.999    |  0.01     |  40.0     |  1e+03    |
# |  10       |  0.5      |  40.0     |  0.1      |  0.5      |  2.0      |  277.5    |
# |  11       |  0.6928   |  40.0     |  0.1      |  0.01     |  40.0     |  746.7    |
# |  12       |  0.6926   |  40.0     |  0.1      |  0.01     |  2.0      |  436.8    |

# %%
# if best model is lr model, run this
LR_PARAMS = {'print':True, 'equation_file':lr_model_equation_file, 'model_summary_file':lr_model_summary_file, 'vif':vif}

# %%
# train lr model
if model_linear:
    model, pred_train_value, pred_val_value, pred_test_value = model_toolkit('lr', df_tr[col], df_tr[label],
                                                                             x_val=df_va[col], y_val=df_va[label],
                                                                             x_test=df_te[col], xgb_params=None,
                                                                             make_prediction=True, **LR_PARAMS)

# %%
# # train the best model
# model, pred_train_value, pred_val_value, pred_test_value = model_toolkit('xgb', df_tr[col], df_tr[label],
#                                                                          x_val=df_va[col], y_val=df_va[label],
#                                                                          x_test=df_te[col], xgb_params=XGB_PARAMS,
#                                                                          make_prediction=True)

# %%
with HiddenPrints():
    _, summary = cv_check(x[col], y, clf_name='xgb', xgb_params=XGB_PARAMS, x_test=None, y_test=None,
                          cv=5, random_state=2019, silent=True)
summary

# %% [markdown]
# ## MODEL EVALUATION

# %%
####################################################################################################
####################################################################################################
######################################                        ######################################
######################################  13. MODEL EVALUATION  ######################################
######################################                        ######################################
####################################################################################################
####################################################################################################

tr, va, te = plot_all_figures(pred_train_value, df_tr[label], pred_val_value, df_va[label],
                              pred_test_value=pred_test_value,
                              real_test_label=df_te[label], pos_label=1)
